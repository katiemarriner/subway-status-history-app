# %%
import pandas as pd

# %%
routesDf = pd.read_table('../raw-data/google_transit/routes.txt', delimiter=',')

# %%
routesDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 9 columns):
# route_id            29 non-null object
# agency_id           29 non-null object
# route_short_name    29 non-null object
# route_long_name     29 non-null object
# route_desc          29 non-null object
# route_type          29 non-null int64
# route_url           29 non-null object
# route_color         26 non-null object
# route_text_color    4 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ KB

# %%
routesDf = routesDf.set_index('route_id')

# %%
routesDf
# Out:
#          agency_id route_short_name                  route_long_name  \
# route_id
# 1         MTA NYCT                1        Broadway - 7 Avenue Local
# 2         MTA NYCT                2                 7 Avenue Express
# 3         MTA NYCT                3                 7 Avenue Express
# 4         MTA NYCT                4         Lexington Avenue Express
# 5         MTA NYCT                5         Lexington Avenue Express
# 5X        MTA NYCT               5X         Lexington Avenue Express
# 6         MTA NYCT                6           Lexington Avenue Local
# 6X        MTA NYCT               6X         Lexington Avenue Express
# 7         MTA NYCT                7                   Flushing Local
# 7X        MTA NYCT               7X                 Flushing Express
# GS        MTA NYCT                S                    42 St Shuttle
# A         MTA NYCT                A                 8 Avenue Express
# ...

# %%
routesDf.to_json('../prod-data/routeDetail.json', orient='index')

# %%
routeIdsDf = routesDf['route_id']

# %%
routeIdsDf.to_json('../prod-data/routeIds.json', orient='records')

# %%
routesDf
# Out:
#          agency_id route_short_name                  route_long_name  \
# route_id
# 1         MTA NYCT                1        Broadway - 7 Avenue Local
# 2         MTA NYCT                2                 7 Avenue Express
# 3         MTA NYCT                3                 7 Avenue Express
# 4         MTA NYCT                4         Lexington Avenue Express
# 5         MTA NYCT                5         Lexington Avenue Express
# 5X        MTA NYCT               5X         Lexington Avenue Express
# 6         MTA NYCT                6           Lexington Avenue Local
# 6X        MTA NYCT               6X         Lexington Avenue Express
# 7         MTA NYCT                7                   Flushing Local
# 7X        MTA NYCT               7X                 Flushing Express
# GS        MTA NYCT                S                    42 St Shuttle
# A         MTA NYCT                A                 8 Avenue Express
# ...
