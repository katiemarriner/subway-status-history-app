# %%
import pandas as pd

# %%
usageSampleDf = pd.read_csv('../raw-data/turnstile-usage/turnstile_170610.txt', header=0)

# %%
usageSampleDf.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6203652
# 1  REGULAR  6203674
# 2  REGULAR  6203688
# 3  REGULAR  6203769
# 4  REGULAR  6203987
#
#    EXITS
# 0                                            2101226
# 1                                            2101230
# 2                                            2101260
# 3                                            2101343
# 4                                            2101401

# %%
usageSampleDf.columns = usageSampleDf.columns.str.strip()

# %%
usageSampleDf.sort_values('EXITS', ascending=False)
# Out:
#          C/A  UNIT       SCP       STATION LINENAME DIVISION        DATE  \
# 69828   N208  R443  01-05-01        170 ST       BD      IND  06/09/2017
# 69798   N208  R443  01-05-01        170 ST       BD      IND  06/04/2017
# 69806   N208  R443  01-05-01        170 ST       BD      IND  06/06/2017
# 69805   N208  R443  01-05-01        170 ST       BD      IND  06/05/2017
# 69804   N208  R443  01-05-01        170 ST       BD      IND  06/05/2017
# 69803   N208  R443  01-05-01        170 ST       BD      IND  06/05/2017
# 69802   N208  R443  01-05-01        170 ST       BD      IND  06/05/2017
# 69801   N208  R443  01-05-01        170 ST       BD      IND  06/05/2017
# 69800   N208  R443  01-05-01        170 ST       BD      IND  06/05/2017
# 69799   N208  R443  01-05-01        170 ST       BD      IND  06/04/2017
# 69788   N208  R443  01-05-01        170 ST       BD      IND  06/03/2017
# 69808   N208  R443  01-05-01        170 ST       BD      IND  06/06/2017
# ...
