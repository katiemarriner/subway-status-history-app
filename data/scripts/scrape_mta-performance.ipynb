# %%
import pandas as pd

# %%
performanceSampleDf = pd.read_csv('../raw-data/MTA_Performance_Datall/MTA_Performance_NYCT.csv', header=0)

# %%
performanceSampleDf
# Out:
#       INDICATOR_SEQ  PARENT_SEQ  AGENCY_NAME  \
# 0             67816           0  NYC Transit
# 1             67816           0  NYC Transit
# 2             67816           0  NYC Transit
# 3             67816           0  NYC Transit
# 4             67816           0  NYC Transit
# 5             67816           0  NYC Transit
# 6             67816           0  NYC Transit
# 7             67816           0  NYC Transit
# 8             67816           0  NYC Transit
# 9             67816           0  NYC Transit
# 10            67816           0  NYC Transit
# 11            67816           0  NYC Transit
# 12            67816           0  NYC Transit
# 13            67816           0  NYC Transit
# 14            67816           0  NYC Transit
# 15            67816           0  NYC Transit
# 16            67816           0  NYC Transit
# 17            67816           0  NYC Transit
# 18            67816           0  NYC Transit
# 19            67816           0  NYC Transit
# ...

# %%
waitAssessment = performanceSampleDf[performanceSampleDf['PARENT_SEQ'] == 392289]

# %%
waitAssessment.groupby('INDICATOR_NAME')['YTD_ACTUAL'].median().sort_values()
# Out:
# INDICATOR_NAME
# Subway Wait Assessment - 5 Line      70.3
# Subway Wait Assessment - A Line      71.6
# Subway Wait Assessment - 4 Line      71.8
# Subway Wait Assessment - 2 Line      72.5
# Subway Wait Assessment - F Line      72.8
# Subway Wait Assessment - 6 Line      73.2
# Subway Wait Assessment - E Line      74.6
# Subway Wait Assessment - 7 Line      75.8
# Subway Wait Assessment - 3 Line      76.9
# Subway Wait Assessment - R Line      77.7
# Subway Wait Assessment - B Line      78.2
# Subway Wait Assessment - M Line      78.6
# Subway Wait Assessment - N Line      78.9
# Subway Wait Assessment - 1 Line      78.9
# Subway Wait Assessment - L Line      79.1
# Subway Wait Assessment - Q Line      79.2
# Subway Wait Assessment - D Line      79.5
# Subway Wait Assessment - C Line      80.0
# Subway Wait Assessment - J Z Line    82.0
# Subway Wait Assessment - G Line      82.0
# Subway Wait Assessment - S 42 St     90.5
# Subway Wait Assessment - S Rock      92.9
# ...
